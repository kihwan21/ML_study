# %% [markdown]
# # 다중분류
# 분류 작업이 3개 이상. 여태까지 한 것은 클래스가 2개인 이진분류
#
# 다중분류는 one vs All 하나의 기준점을 맞춘 클래스로 이루어짐
#
# 각 클래스 i에 대해서 로지스틱 회귀를 휸련하고 y = i일 확률을 예측함.
# 새로운 입력 x에 대한 분류를 위해 h0(x)를 최대화 하는 i를 선택 argmax h0i(x)
