# %%
#submit = pd.read_csv("sample_submit.csv")   # 데이터 셋 제출

# submit['species'] = y_test_pred_org
#submit.to_csv("김기환_2019680078_1.csv", mode="w", header = True, index = False)

# %%
import pandas as pd


xy_train = pd.read_csv("iris-train.csv")
xy_test = pd.read_csv("iris-test.csv")

# print(xy_train.head())
# print(xy_test.head())

#Labe Encoder 클래스 범주형 자료 실수화 
from sklearn.preprocessing import  LabelEncoder
import numpy as np
classle = LabelEncoder()


# X에다 species를 제외한 값 넣기
X = xy_train.drop('species', axis=1)


xy_train = classle.fit_transform(xy_train['species'].values)



print(X)
print(y)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.5          4.2           1.4          0.2
# 1             5.4          3.4           1.7          0.2
# 2             6.4          3.2           5.3          2.3
# 3             6.7          3.3           5.7          2.1
# 4             5.0          3.2           1.2          0.2
# ..            ...          ...           ...          ...
# 100           4.5          2.3           1.3          0.3
# 101           5.8          2.6           4.0          1.2
# 102           5.0          3.4           1.6          0.4
# 103           4.6          3.1           1.5          0.2
# 104           4.4          3.2           1.3          0.2
#
# [105 rows x 4 columns]
# 0          setosa
# 1          setosa
# 2       virginica
# 3       virginica
# 4          setosa
#           ...
# 100        setosa
# 101    versicolor
# 102        setosa
# 103        setosa
# 104        setosa
# ...
