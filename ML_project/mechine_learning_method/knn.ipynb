# %%
import seaborn as sns   # iris같은 데이터 셋이 있는 모듈
import numpy as np

iris = sns.load_dataset('iris')       # iris 라는 변수명으로 iris 다운
type(iris)

sns.set()   # style로 그림 그려서 데이터 값을 확인 가능
sns.pairplot(iris, hue='species', height=2.5) #height: 그림 크기 # hue = 'species' 칼럼 네임 열

# %%
import seaborn as sns   # iris같은 데이터 셋이 있는 모듈
import numpy as np

iris = sns.load_dataset('iris')       # iris 라는 변수명으로 iris 다운
type(iris)

sns.set()   # style로 그림 그려서 데이터 값을 확인 가능
sns.pairplot(iris, hue='sepal_width', height=2.5) #height:그림 크기 # hue 원하는 열 이름을 입력해서 해당 열을 기준으로 그래프 출력

# %%
sns.pairplot(iris, hue='petal_length')

# %%
import seaborn as sns   # iris같은 데이터 셋이 있는 모듈
import numpy as np

iris = sns.load_dataset('iris')       # iris 라는 변수명으로 iris 다운
type(iris)

sns.set()   # style로 그림 그려서 데이터 값을 확인 가능
sns.pairplot(iris, hue='species', height=2.5) #height: 그림 크기 # hue = 'species' 칼럼 네임 열

# %%
iris.to_csv('submit.csv', mode='w', header= True, index= False)
type(iris)

# %%
from sklearn.preprocessing import LabelEncoder      
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split

iris = sns.load_dataset('iris') 
iris.to_csv('submit.csv', mode='w', header= True, index= False)

classle = LabelEncoder() #'species'열의 문자열을 categorical value로 전환 
y = classle.fit_transform(iris['species'].values) #데이터 전처리 함.
print('species labels:', np.unique(y)) 

yo = classle.inverse_transform(y)
print(np.unique(yo))

X = iris.drop('species', axis=1)    # axis = 1 열 
y = iris['species']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1, stratify=y)
a, b = np.unique(y_train, return_counts=True)
c = dict(zip(a, b))

print(c)
# 각 데이터 구조 확인
print('입력변수(학습데이터)    : ',  X_train.shape)
print('입력변수(테스트데이터)  : ', X_test.shape)
print('종속변수(학습데이터)    : ',  y_train.shape)
print('종속변수(테스트데이터)  : ', y_test.shape)
# Out:
# species labels: [0 1 2]
# ['setosa' 'versicolor' 'virginica']
# {'setosa': 35, 'versicolor': 35, 'virginica': 35}
# 입력변수(학습데이터)    :  (105, 4)
# 입력변수(테스트데이터)  :  (45, 4)
# 종속변수(학습데이터)    :  (105,)
# 종속변수(테스트데이터)  :  (45,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder      
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
import seaborn as sns

iris = sns.load_dataset('iris') 
iris.to_csv('submit.csv', mode='w', header= True, index= False)

classle = LabelEncoder() 
y = classle.fit_transform(iris['species'].values) #데이터 전처리 함.

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y) # test_size=0.3 비율을 7:3

print(X_test.shape)
print(X_train.shape)
print(y_test.shape)
print(y_train.shape)

knn = KNeighborsClassifier(n_neighbors=5, p=2)
# Out:
# (45, 4)
# (105, 4)
# (45,)
# (105,)
