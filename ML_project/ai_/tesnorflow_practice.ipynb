# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# fashion MNIST 데이터셋을 읽어와 신경망에 입력할 형태로 변환
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train = x_train.reshape(60000,784) # 텐서 모양 변환
x_test = x_test.reshape(10000,784)
x_train=x_train.astype(np.float32)/255.0 # ndarray로 변환
x_test=x_test.astype(np.float32)/255.0
y_train=tf.keras.utils.to_categorical(y_train,10) # 원핫 코드로 변환
y_test=tf.keras.utils.to_categorical(y_test,10)

                                                            
n_input=784
n_hidden=1024
n_output=10

mlp=Sequential()
mlp.add (Dense(units=n_hidden,activation='tanh',input_shape=(n_input,),kernel_initializer='random_uniform',bias_initializer='zeros'))
mlp.add(Dense(units=n_output,activation='tanh',kernel_initializer='random_uniform',bias_initializer='zeros'))

mlp.compile(loss='mean_squared_error',optimizer=Adam(learning_rate=0.001),metrics=['accuracy'])
hist=mlp.fit(x_train,y_train,batch_size=128,epochs=30,validation_data=(x_test,y_test),verbose=2)

res=mlp.evaluate(x_test,y_test,verbose=0)
print("정확률은",res[1]*100)
import matplotlib.pyplot as plt

# 정확률 곡선
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'], loc='upper left')
plt.grid()
plt.show()

# 손실 함수 곡선
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'], loc='upper right')
plt.grid()
plt.show()
# Out:
# C:\Users\vlrms\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\requests\__init__.py:104: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (5.0.0)/charset_normalizer (2.0.10) doesn't match a supported version!
#   RequestsDependencyWarning)
# Epoch 1/30
# 469/469 - 5s - loss: 0.0950 - accuracy: 0.4547 - val_loss: 0.0351 - val_accuracy: 0.8199 - 5s/epoch - 10ms/step
# Epoch 2/30
# 469/469 - 4s - loss: 0.0302 - accuracy: 0.8443 - val_loss: 0.0298 - val_accuracy: 0.8409 - 4s/epoch - 8ms/step
# Epoch 3/30
# 469/469 - 4s - loss: 0.0272 - accuracy: 0.8578 - val_loss: 0.0310 - val_accuracy: 0.8472 - 4s/epoch - 8ms/step
# Epoch 4/30
# 469/469 - 4s - loss: 0.0250 - accuracy: 0.8679 - val_loss: 0.0250 - val_accuracy: 0.8580 - 4s/epoch - 8ms/step
# Epoch 5/30
# 469/469 - 4s - loss: 0.0236 - accuracy: 0.8755 - val_loss: 0.0254 - val_accuracy: 0.8604 - 4s/epoch - 9ms/step
# Epoch 6/30
# 469/469 - 4s - loss: 0.0224 - accuracy: 0.8809 - val_loss: 0.0237 - val_accuracy: 0.8661 - 4s/epoch - 9ms/step
# Epoch 7/30
# 469/469 - 4s - loss: 0.0219 - accuracy: 0.8857 - val_loss: 0.0238 - val_accuracy: 0.8722 - 4s/epoch - 10ms/step
# Epoch 8/30
# 469/469 - 4s - loss: 0.0207 - accuracy: 0.8891 - val_loss: 0.0230 - val_accuracy: 0.8732 - 4s/epoch - 9ms/step
# Epoch 9/30
# 469/469 - 4s - loss: 0.0200 - accuracy: 0.8937 - val_loss: 0.0229 - val_accuracy: 0.8732 - 4s/epoch - 9ms/step
# Epoch 10/30
# 469/469 - 5s - loss: 0.0196 - accuracy: 0.8970 - val_loss: 0.0218 - val_accuracy: 0.8815 - 5s/epoch - 10ms/step
# Epoch 11/30
# 469/469 - 4s - loss: 0.0187 - accuracy: 0.9009 - val_loss: 0.0221 - val_accuracy: 0.8765 - 4s/epoch - 10ms/step
# Epoch 12/30
# 469/469 - 4s - loss: 0.0189 - accuracy: 0.9027 - val_loss: 0.0226 - val_accuracy: 0.8811 - 4s/epoch - 9ms/step
# Epoch 13/30
# 469/469 - 5s - loss: 0.0181 - accuracy: 0.9059 - val_loss: 0.0217 - val_accuracy: 0.8810 - 5s/epoch - 10ms/step
# Epoch 14/30
# 469/469 - 4s - loss: 0.0176 - accuracy: 0.9084 - val_loss: 0.0212 - val_accuracy: 0.8818 - 4s/epoch - 9ms/step
# Epoch 15/30
# 469/469 - 4s - loss: 0.0175 - accuracy: 0.9098 - val_loss: 0.0203 - val_accuracy: 0.8851 - 4s/epoch - 9ms/step
# Epoch 16/30
# 469/469 - 4s - loss: 0.0169 - accuracy: 0.9136 - val_loss: 0.0215 - val_accuracy: 0.8837 - 4s/epoch - 9ms/step
# Epoch 17/30
# 469/469 - 4s - loss: 0.0165 - accuracy: 0.9158 - val_loss: 0.0214 - val_accuracy: 0.8857 - 4s/epoch - 9ms/step
# Epoch 18/30
# 469/469 - 4s - loss: 0.0164 - accuracy: 0.9176 - val_loss: 0.0198 - val_accuracy: 0.8916 - 4s/epoch - 8ms/step
# Epoch 19/30
# 469/469 - 4s - loss: 0.0160 - accuracy: 0.9198 - val_loss: 0.0196 - val_accuracy: 0.8894 - 4s/epoch - 10ms/step
# Epoch 20/30
# 469/469 - 5s - loss: 0.0157 - accuracy: 0.9223 - val_loss: 0.0205 - val_accuracy: 0.8917 - 5s/epoch - 12ms/step
# Epoch 21/30
# 469/469 - 5s - loss: 0.0154 - accuracy: 0.9235 - val_loss: 0.0204 - val_accuracy: 0.8893 - 5s/epoch - 10ms/step
# Epoch 22/30
# 469/469 - 4s - loss: 0.0151 - accuracy: 0.9264 - val_loss: 0.0195 - val_accuracy: 0.8901 - 4s/epoch - 9ms/step
# Epoch 23/30
# 469/469 - 4s - loss: 0.0146 - accuracy: 0.9287 - val_loss: 0.0199 - val_accuracy: 0.8902 - 4s/epoch - 9ms/step
# Epoch 24/30
# 469/469 - 5s - loss: 0.0144 - accuracy: 0.9306 - val_loss: 0.0206 - val_accuracy: 0.8908 - 5s/epoch - 10ms/step
# Epoch 25/30
# 469/469 - 5s - loss: 0.0143 - accuracy: 0.9323 - val_loss: 0.0186 - val_accuracy: 0.8938 - 5s/epoch - 11ms/step
# Epoch 26/30
# 469/469 - 6s - loss: 0.0141 - accuracy: 0.9344 - val_loss: 0.0190 - val_accuracy: 0.8948 - 6s/epoch - 14ms/step
# Epoch 27/30
# 469/469 - 8s - loss: 0.0138 - accuracy: 0.9360 - val_loss: 0.0197 - val_accuracy: 0.8945 - 8s/epoch - 17ms/step
# Epoch 28/30
# 469/469 - 12s - loss: 0.0137 - accuracy: 0.9376 - val_loss: 0.0201 - val_accuracy: 0.8940 - 12s/epoch - 26ms/step
# Epoch 29/30
# 469/469 - 8s - loss: 0.0133 - accuracy: 0.9387 - val_loss: 0.0187 - val_accuracy: 0.8982 - 8s/epoch - 16ms/step
# Epoch 30/30
# 469/469 - 6s - loss: 0.0131 - accuracy: 0.9402 - val_loss: 0.0193 - val_accuracy: 0.8957 - 6s/epoch - 12ms/step
# 정확률은 89.56999778747559

# %%
import tensorflow as tf
import tensorflow.keras.datasets as  ds

# MNIST읽고 텐서 모양 출력
(x_train, y_train), (x_test, y_test) = ds.mnist.load_data()
yy_train = tf.one_hot(y_train, 10, dtype=tf.int8)       # 레이블 정보를 원핫 코드로 변환 
#print("MNIST: ", x_train, y_train.shape, y_train.shape, yy_train.shape.shape)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# fashion MNIST 데이터셋을 읽어와 신경망에 입력할 형태로 변환
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train = x_train.reshape(60000,784) # 텐서 모양 변환
x_test = x_test.reshape(10000,784)
x_train=x_train.astype(np.float32)/255.0 # ndarray로 변환
x_test=x_test.astype(np.float32)/255.0
y_train=tf.keras.utils.to_categorical(y_train,10) # 원핫 코드로 변환
y_test=tf.keras.utils.to_categorical(y_test,10)

n_input=784
n_hidden=100
n_output=10

# %%
mlp=Sequential()
mlp.add (Dense(units=n_hidden,activation='tanh',input_shape=(n_input,),kernel_initializer='random_uniform',bias_initializer='zeros'))
mlp.add(Dense(units=n_output,activation='tanh',kernel_initializer='random_uniform',bias_initializer='zeros'))

mlp.compile(loss='mean_squared_error',optimizer=Adam(learning_rate=0.001),metrics=['accuracy'])
hist=mlp.fit(x_train,y_train,batch_size=30,epochs=30,validation_data=(x_test,y_test),verbose=2)

res=mlp.evaluate(x_test,y_test,verbose=0)
print("정확률은",res[1]*100)
import matplotlib.pyplot as plt

# 정확률 곡선
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'], loc='upper left')
plt.grid()
plt.show()

# 손실 함수 곡선
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'], loc='upper right')
plt.grid()
plt.show()
# Out:
# Epoch 1/30
# 2000/2000 - 8s - loss: 0.0308 - accuracy: 0.8223 - val_loss: 0.0259 - val_accuracy: 0.8466 - 8s/epoch - 4ms/step
# Epoch 2/30
# 2000/2000 - 6s - loss: 0.0236 - accuracy: 0.8615 - val_loss: 0.0242 - val_accuracy: 0.8571 - 6s/epoch - 3ms/step
# Epoch 3/30
# 2000/2000 - 6s - loss: 0.0217 - accuracy: 0.8741 - val_loss: 0.0234 - val_accuracy: 0.8563 - 6s/epoch - 3ms/step
# Epoch 4/30
# 2000/2000 - 6s - loss: 0.0206 - accuracy: 0.8791 - val_loss: 0.0229 - val_accuracy: 0.8601 - 6s/epoch - 3ms/step
# Epoch 5/30
# 2000/2000 - 6s - loss: 0.0198 - accuracy: 0.8846 - val_loss: 0.0216 - val_accuracy: 0.8672 - 6s/epoch - 3ms/step
# Epoch 6/30
# 2000/2000 - 5s - loss: 0.0191 - accuracy: 0.8895 - val_loss: 0.0226 - val_accuracy: 0.8670 - 5s/epoch - 3ms/step
# Epoch 7/30
# 2000/2000 - 5s - loss: 0.0187 - accuracy: 0.8904 - val_loss: 0.0210 - val_accuracy: 0.8729 - 5s/epoch - 3ms/step
# Epoch 8/30
# 2000/2000 - 6s - loss: 0.0182 - accuracy: 0.8938 - val_loss: 0.0211 - val_accuracy: 0.8722 - 6s/epoch - 3ms/step
# Epoch 9/30
# 2000/2000 - 6s - loss: 0.0179 - accuracy: 0.8969 - val_loss: 0.0205 - val_accuracy: 0.8748 - 6s/epoch - 3ms/step
# Epoch 10/30
# 2000/2000 - 7s - loss: 0.0176 - accuracy: 0.8989 - val_loss: 0.0214 - val_accuracy: 0.8746 - 7s/epoch - 3ms/step
# Epoch 11/30
# 2000/2000 - 10s - loss: 0.0174 - accuracy: 0.9008 - val_loss: 0.0220 - val_accuracy: 0.8659 - 10s/epoch - 5ms/step
# Epoch 12/30
# 2000/2000 - 9s - loss: 0.0171 - accuracy: 0.9014 - val_loss: 0.0205 - val_accuracy: 0.8737 - 9s/epoch - 4ms/step
# Epoch 13/30
# 2000/2000 - 10s - loss: 0.0169 - accuracy: 0.9032 - val_loss: 0.0202 - val_accuracy: 0.8771 - 10s/epoch - 5ms/step
# Epoch 14/30
# 2000/2000 - 8s - loss: 0.0167 - accuracy: 0.9047 - val_loss: 0.0201 - val_accuracy: 0.8781 - 8s/epoch - 4ms/step
# Epoch 15/30
# 2000/2000 - 9s - loss: 0.0165 - accuracy: 0.9064 - val_loss: 0.0208 - val_accuracy: 0.8735 - 9s/epoch - 5ms/step
# Epoch 16/30
# 2000/2000 - 11s - loss: 0.0164 - accuracy: 0.9079 - val_loss: 0.0206 - val_accuracy: 0.8751 - 11s/epoch - 6ms/step
# Epoch 17/30
# 2000/2000 - 11s - loss: 0.0162 - accuracy: 0.9091 - val_loss: 0.0215 - val_accuracy: 0.8700 - 11s/epoch - 5ms/step
# Epoch 18/30
# 2000/2000 - 8s - loss: 0.0160 - accuracy: 0.9103 - val_loss: 0.0212 - val_accuracy: 0.8743 - 8s/epoch - 4ms/step
# Epoch 19/30
# 2000/2000 - 9s - loss: 0.0159 - accuracy: 0.9114 - val_loss: 0.0207 - val_accuracy: 0.8746 - 9s/epoch - 5ms/step
# Epoch 20/30
# 2000/2000 - 8s - loss: 0.0157 - accuracy: 0.9136 - val_loss: 0.0211 - val_accuracy: 0.8730 - 8s/epoch - 4ms/step
# Epoch 21/30
# 2000/2000 - 8s - loss: 0.0156 - accuracy: 0.9143 - val_loss: 0.0212 - val_accuracy: 0.8726 - 8s/epoch - 4ms/step
# Epoch 22/30
# 2000/2000 - 7s - loss: 0.0155 - accuracy: 0.9140 - val_loss: 0.0213 - val_accuracy: 0.8736 - 7s/epoch - 4ms/step
# Epoch 23/30
# 2000/2000 - 6s - loss: 0.0153 - accuracy: 0.9165 - val_loss: 0.0215 - val_accuracy: 0.8747 - 6s/epoch - 3ms/step
# Epoch 24/30
# 2000/2000 - 11s - loss: 0.0152 - accuracy: 0.9164 - val_loss: 0.0208 - val_accuracy: 0.8774 - 11s/epoch - 6ms/step
# Epoch 25/30
# 2000/2000 - 8s - loss: 0.0151 - accuracy: 0.9181 - val_loss: 0.0214 - val_accuracy: 0.8740 - 8s/epoch - 4ms/step
# Epoch 26/30
# 2000/2000 - 10s - loss: 0.0150 - accuracy: 0.9184 - val_loss: 0.0203 - val_accuracy: 0.8775 - 10s/epoch - 5ms/step
# Epoch 27/30
# 2000/2000 - 9s - loss: 0.0149 - accuracy: 0.9201 - val_loss: 0.0215 - val_accuracy: 0.8735 - 9s/epoch - 4ms/step
# Epoch 28/30
# 2000/2000 - 7s - loss: 0.0148 - accuracy: 0.9200 - val_loss: 0.0207 - val_accuracy: 0.8759 - 7s/epoch - 4ms/step
# Epoch 29/30
# 2000/2000 - 7s - loss: 0.0147 - accuracy: 0.9208 - val_loss: 0.0203 - val_accuracy: 0.8772 - 7s/epoch - 3ms/step
# Epoch 30/30
# 2000/2000 - 6s - loss: 0.0147 - accuracy: 0.9218 - val_loss: 0.0212 - val_accuracy: 0.8738 - 6s/epoch - 3ms/step
# 정확률은 87.3799979686737
