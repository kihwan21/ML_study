# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/Users/vlrms/Desktop/데이터분석/Forbes_2000_top_company_CLNQ11.csv")
data

# 1등부터 2000까지 시가총액
# Out:
#       2022 Ranking                          Organization Name  \
# 0                1                         Berkshire Hathaway
# 1                2                                       ICBC
# 2                3   Saudi Arabian Oil Company (Saudi Aramco)
# 3                4                             JPMorgan Chase
# 4                5                    China Construction Bank
# ...            ...                                        ...
# 1994          1995                                     Aperam
# 1995          1995  Shenzhen Feima International Supply Chain
# 1996          1997                                       NMDC
# 1997          1997                 Sichuan Changhong Electric
# 1998          1999                         Satellite Chemical
#
#                           Industry        Country  Year Founded  \
# 0           Diversified Financials  United States          1939
# 1                          Banking          China          1984
# ...

# %%
print(data.isnull().sum()) # 결측값은 보이지 않음
# Out:
# 2022 Ranking               0
# Organization Name          0
# Industry                   0
# Country                    0
# Year Founded               0
# CEO                        0
# Revenue (Billions)         0
# Profits (Billions)         0
# Assets (Billions)          0
# Market Value (Billions)    0
# Total Employees            0
# dtype: int64

# %%
data.dtypes
# Out:
# 2022 Ranking                 int64
# Organization Name           object
# Industry                    object
# Country                     object
# Year Founded                 int64
# CEO                         object
# Revenue (Billions)         float64
# Profits (Billions)         float64
# Assets (Billions)          float64
# Market Value (Billions)    float64
# Total Employees             object
# dtype: object

# %%
data.describe()
# Out:
#        2022 Ranking  Year Founded  Revenue (Billions)  Profits (Billions)  \
# count   1999.000000   1999.000000         1999.000000         1999.000000
# mean     999.818409   1863.992496           23.886628            2.503167
# std      577.098137    421.815723           40.951362            6.160483
# min        1.000000      0.000000            0.000000          -12.050000
# 25%      500.500000   1919.000000            5.600000            0.590000
# 50%     1000.000000   1971.000000           12.170000            1.060000
# 75%     1499.000000   1996.000000           23.730000            2.270000
# max     1999.000000   2022.000000          572.750000          105.360000
#
#        Assets (Billions)  Market Value (Billions)
# count        1999.000000              1999.000000
# mean          117.176013                38.260675
# std           363.826515               117.233301
# min             0.170000                 0.140000
# ...

# %%
data.nunique()  # 총 국가는 57개, 산업군은 29개
# Out:
# 2022 Ranking               1684
# Organization Name          1999
# Industry                     29
# Country                      57
# Year Founded                214
# CEO                        1963
# Revenue (Billions)         1587
# Profits (Billions)          688
# Assets (Billions)          1790
# Market Value (Billions)    1665
# Total Employees            1748
# dtype: int64

# %%
import seaborn as sns

country = data["Country"].sort_index(ascending = True)  

country_counts = data["Country"].unique()
# 한글 폰트 적용
plt.rc('font', family='NanumBarunGothic') 
# 캔버스 사이즈 적용
plt.rcParams["figure.figsize"] = (20, 20)

sns.countplot(y=country)

plt.show()

# %%
# ABC순서대로 

import seaborn as sns

country = data["Country"]
country_counts = country.sort_values(ascending=True)  #인덱스 안에 있는 데이터 값으로 정렬 
# 한글 폰트 적용
plt.rc('font', family='NanumBarunGothic') 
# 캔버스 사이즈 적용
plt.rcParams["figure.figsize"] = (20, 20)

sns.countplot(y=country_counts)

plt.show()

# %%
# 어떤 분야의 기업이 많은지 확인 

import seaborn as sns

Industry = data["Industry"].sort_index(ascending = True)  

# 한글 폰트 적용
plt.rc('font', family='NanumBarunGothic') 
# 캔버스 사이즈 적용
plt.rcParams["figure.figsize"] = (25, 25)

sns.countplot(y=Industry)

plt.show()

# %%
# 어떤 분야의 기업이 많은지 확인 

import seaborn as sns

Industry = data["Industry"].sort_values(ascending = True)

# 한글 폰트 적용
plt.rc('font', family='NanumBarunGothic') 
# 캔버스 사이즈 적용
plt.rcParams["figure.figsize"] = (25, 25)

sns.countplot(y=Industry)

plt.show()

# %%
import plotly.graph_objects as go

fig = go.Figure(data=go.Scatter(x=data['Revenue (Billions)'], y=data['Profits (Billions)'], mode='markers'))
fig.update_layout(title='Revenue vs Profits',xaxis_title='Revenue (Billions)',yaxis_title='Profits (Billions)')
fig.show()

# %%
import seaborn as sns

Industry = data["Industry"].sort_values(ascending = True)
Revenue = data["Revenue (Billions)"].sort_values(ascending = True)

plt.bar(Industry, Revenue)
plt.title('Best Company in each Industry (by Revenue)')
plt.xlabel('Industry')
plt.ylabel('Revenue (Billions)')
plt.xticks(rotation=70)
plt.rcParams["figure.figsize"] = (15, 15)
plt.show()

# %%
df = pd.read_csv("C:/Users/vlrms/Desktop/데이터분석/Forbes_2000_top_company_CLNQ11.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1999 entries, 0 to 1998
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   2022 Ranking             1999 non-null   int64
#  1   Organization Name        1999 non-null   object
#  2   Industry                 1999 non-null   object
#  3   Country                  1999 non-null   object
#  4   Year Founded             1999 non-null   int64
#  5   CEO                      1999 non-null   object
#  6   Revenue (Billions)       1999 non-null   float64
#  7   Profits (Billions)       1999 non-null   float64
#  8   Assets (Billions)        1999 non-null   float64
#  9   Market Value (Billions)  1999 non-null   float64
#  10  Total Employees          1999 non-null   object
# dtypes: float64(4), int64(2), object(5)
# memory usage: 171.9+ KB

# %%
import plotly.express as px

# %%
fig = px.bar(df, x='Industry', y='Industry', color='Industry', 
             title='Distribution of Companies Across Industries',
             labels={'Industry':'Industry'}, 
             height=800)
fig.update_layout(title_font=dict(size=24),
                  xaxis_title_font=dict(size=20),
                  yaxis_title_font=dict(size=20),
                  xaxis_tickfont=dict(size=14),
                  yaxis_tickfont=dict(size=14)
                  )
fig.show()

# %%
fig = px.bar(df, x='Country', y='Country', color='Country',
             title='Number of Companies in Each Country',
             labels={'Country':'Country'},
             height=800)
fig.update_xaxes(tickangle=90)
fig.show()

# %%
best_org = df.loc[df.groupby('Industry')['Revenue (Billions)'].idxmax()]
best_org = best_org[['Industry','Organization Name','Revenue (Billions)','Profits (Billions)','Assets (Billions)','Market Value (Billions)']]
best_org = best_org.set_index('Industry')
best_org
# Out:
#                                                          Organization Name  \
# Industry
# Aerospace & Defense                                        Lockheed Martin
# Automotive                                                          Rivian
# Banking                                                               ICBC
# Business Services & Supplies                                    Fannie Mae
# Capital Goods                                                  Caterpillar
# Chemicals                                                             BASF
# Conglomerates                                                      Hitachi
# Construction                          China State Construction Engineering
# Consumer Durables                                         Volkswagen Group
# Diversified Financials                                  Berkshire Hathaway
# Drugs & Biotechnology                                             McKesson
# ...

# %%
top_revenue_by_country = df.loc[df.groupby('Country')['Revenue (Billions)'].idxmax()]

# %%
import random
import plotly.graph_objects as go
import plotly

top_revenue_by_country = df.loc[df.groupby('Country')['Revenue (Billions)'].nlargest(10).reset_index(level=0, drop=True).index]

for country in top_revenue_by_country['Country'].unique():
    country_df = top_revenue_by_country[top_revenue_by_country['Country'] == country]
    fig = go.Figure(data=[go.Pie(labels=country_df['Organization Name'], values=country_df['Revenue (Billions)'], 
                              hole=.3, textinfo='label+percent',marker=dict(colors=random.choices(plotly.colors.DEFAULT_PLOTLY_COLORS)))])
    fig.update_layout(title=f'Top 10 Grossing Companies in {country}', width=700, height=400)
    fig.show()

# %%
미국은 물류, 석유, IT, 유통, 
united health group  <--- 의료산업의 시가총액이 높다는 건 기업화 되어있다는 것
